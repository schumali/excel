# %%
import pandas as pd
import os

# %%
data = pd.read_excel(r"C:\Users\lijie\demo\data\split\6-20-6-22上海地址的签收了报单.xlsx", skiprows= 0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   QQ        52 non-null     object
#  1   几号签收的     51 non-null     object
#  2   是什么货      52 non-null     object
#  3   物流单号多少    52 non-null     object
#  4   几单        52 non-null     int64
#  5   总共几个      52 non-null     object
#  6   付了多少钱     52 non-null     object
#  7   我要给你多少钱   52 non-null     object
#  8   支付宝账号+名字  52 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 3.8+ KB

# %%
data
# Out:
#                  QQ        几号签收的  \
# 0    3202611878+小米多       6.21签收
# 1         846528789          21号
# 2         526144761  18号下单 21号签收
# 3         178574794           20
# 4      630922605+媚儿         6.21
# 5        1946119385     20号  签收了
# 6         852868456        22号签收
# 7        1946119385       21号签收了
# 8         359378054           20
# 9        1712386467         6.21
# 10       1712386467         6.20
# 11       1712386467         6.21
# 12       1712386467         6.21
# 13       1712386467         6.21
# 14       1712386467         6.20
# 15       1712386467         6.20
# 16        472605556           22
# 17        472605556           22
# 18       1151628908           21
# 19        215292325           21
# 20        296505649          20号
# 21       1712386467         6.21
# 22       1712386467         6.21
# 23       1712386467         6.21
# 24        178574794           22
# 25  SN2B00202518601           22
# 26        359378054           20
# ...

# %%
data_wuliu = data["物流单号多少"].str.split('，',expand = True)

# %% [markdown]
# #选择清洗的列

# %%
data_wuliu
# Out:
#                                                     0                 1  \
# 0   0018874835090101  +黑色+赠品耳机\n0018873102430101  ...              None
# 1                                    0018837872390101              None
# 2                  0018852225460101\n0047298688860101              None
# 3                                     SF1191569826716              None
# 4                   0018874775160101+0018874775160201              None
# 5                                    0047291449010101              None
# 6                                  0018852201660101\n              None
# 7                                    0047293341850101              None
# 8                                    0018848145470101              None
# 9                                     JD0019460099570              None
# 10                                苏宁；0018847225330101              None
# 11         苏宁：0018846707780101  \n苏宁：0018826271860101              None
# ...

# %% [markdown]
# #行转列(堆叠)

# %%
data_wuliu = data_wuliu.stack()
data_wuliu
# Out:
# 0   0    0018874835090101  +黑色+赠品耳机\n0018873102430101  ...
# 1   0                                     0018837872390101
# 2   0                   0018852225460101\n0047298688860101
# 3   0                                      SF1191569826716
# 4   0                    0018874775160101+0018874775160201
# 5   0                                     0047291449010101
# 6   0                                   0018852201660101\n
# 7   0                                     0047293341850101
# 8   0                                     0018848145470101
# 9   0                                      JD0019460099570
# 10  0                                  苏宁；0018847225330101
# 11  0           苏宁：0018846707780101  \n苏宁：0018826271860101
# 12  0                          京东：JDX001865645977-1-2  字母件
# 13  0                              JDX001865645977-1-1 字母件
# 14  0                                        124546457644
# 15  0                                         118984098419
# ...

# %%
#清除/重置多余的索引
data_wuliu = data_wuliu.reset_index(level = 1,drop= True)
data_wuliu
# Out:
# 0     0018874835090101  +黑色+赠品耳机\n0018873102430101  ...
# 1                                      0018837872390101
# 2                    0018852225460101\n0047298688860101
# 3                                       SF1191569826716
# 4                     0018874775160101+0018874775160201
# 5                                      0047291449010101
# 6                                    0018852201660101\n
# 7                                      0047293341850101
# 8                                      0018848145470101
# 9                                       JD0019460099570
# 10                                  苏宁；0018847225330101
# 11           苏宁：0018846707780101  \n苏宁：0018826271860101
# 12                          京东：JDX001865645977-1-2  字母件
# 13                              JDX001865645977-1-1 字母件
# 14                                        124546457644
# 15                                         118984098419
# 16                                     0047317032320101
# ...

# %%
data_wuliu.name = data_wuliu
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e6ff4441bd61> in <module>
# ----> 1 data_wuliu.name = data_wuliu
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in name(self, value)
#     493     def name(self, value: Label) -> None:
#     494         if not is_hashable(value):
# --> 495             raise TypeError("Series.name must be a hashable type")
#     496         object.__setattr__(self, "_name", value)
#     497
#
# TypeError: Series.name must be a hashable type

# %%
data_wuliu.rename('data_wuliu')
# Out:
# 0     0018874835090101  +黑色+赠品耳机\n0018873102430101  ...
# 1                                      0018837872390101
# 2                    0018852225460101\n0047298688860101
# 3                                       SF1191569826716
# 4                     0018874775160101+0018874775160201
# 5                                      0047291449010101
# 6                                    0018852201660101\n
# 7                                      0047293341850101
# 8                                      0018848145470101
# 9                                       JD0019460099570
# 10                                  苏宁；0018847225330101
# 11           苏宁：0018846707780101  \n苏宁：0018826271860101
# 12                          京东：JDX001865645977-1-2  字母件
# 13                              JDX001865645977-1-1 字母件
# 14                                        124546457644
# 15                                         118984098419
# 16                                     0047317032320101
# ...

# %%
#和原始数据合并(需要特别注意的是，需要使用原始的连接新生成的，因为新生成的是一个series没有join方法，也可以通过将生成的series通过to_frame方法转换成DataFrame，这样就没有什么差异了)
#data_new = data.drop(['物流单号多少'],axis= 1).join(data_wuliu)
data_new = data.drop(['物流单号多少'], axis=1).join(data_wuliu.to_frame())

# %%
data_new
# Out:
#                  QQ        几号签收的  \
# 0    3202611878+小米多       6.21签收
# 1         846528789          21号
# 2         526144761  18号下单 21号签收
# 3         178574794           20
# 4      630922605+媚儿         6.21
# 5        1946119385     20号  签收了
# 6         852868456        22号签收
# 7        1946119385       21号签收了
# 8         359378054           20
# 9        1712386467         6.21
# 10       1712386467         6.20
# 11       1712386467         6.21
# 12       1712386467         6.21
# 13       1712386467         6.21
# 14       1712386467         6.20
# 15       1712386467         6.20
# 16        472605556           22
# 16        472605556           22
# 16        472605556           22
# 16        472605556           22
# 16        472605556           22
# 17        472605556           22
# 18       1151628908           21
# 19        215292325           21
# 20        296505649          20号
# 21       1712386467         6.21
# 22       1712386467         6.21
# ...

# %%
data_new = data.drop(['物流单号多少'], axis=1).merge(data_wuliu)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-2df30f49a7db> in <module>
# ----> 1 data_new = data.drop(['物流单号多少'], axis=1).merge(data_wuliu)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ...
